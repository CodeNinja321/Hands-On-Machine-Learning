# %%
import pandas as pd

# %%
s = pd.Series([2, -1, 3, 5])
s
# Out:
# 0    2
# 1   -1
# 2    3
# 3    5
# dtype: int64

# %%
import numpy as np
np.exp(s)
# Out:
# 0      7.389056
# 1      0.367879
# 2     20.085537
# 3    148.413159
# dtype: float64

# %%
s + [1000,2000,3000,4000]
# Out:
# 0    1002
# 1    1999
# 2    3003
# 3    4005
# dtype: int64

# %%
s + 1000
# Out:
# 0    1002
# 1     999
# 2    1003
# 3    1005
# dtype: int64

# %%
s < 0
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
s2 = pd.Series([68, 83, 112, 68], index=['Alice', 'Bob', 'Charles', 'Darwin'])
s2
# Out:
# Alice       68
# Bob         83
# Charles    112
# Darwin      68
# dtype: int64

# %%
s2['Bob']
# Out:
# 83

# %%
s2[1]
# Out:
# 83

# %%
s2.loc['Bob']
# Out:
# 83

# %%
s2.iloc[1]
# Out:
# 83

# %%
s2.iloc[1:3]
# Out:
# Bob         83
# Charles    112
# dtype: int64

# %%
surprise = pd.Series([1000, 1001, 1002, 1003])
surprise
# Out:
# 0    1000
# 1    1001
# 2    1002
# 3    1003
# dtype: int64

# %%
surprise_slice = surprise[2:]
surprise_slice
# Out:
# 2    1002
# 3    1003
# dtype: int64

# %%
try:
    surprise_slice[0]
except KeyError as e:
    print("Key error:", e)
# Out:
# Key error: 0

# %%
surprise_slice.iloc[0]
# Out:
# 1002

# %%
weights = {'Alice': 68, 'Bob': 83, 'Colin':86, 'Darwin':68}
print(weights)
s3 = pd.Series(weights)
s3
# Out:
# {'Alice': 68, 'Bob': 83, 'Colin': 86, 'Darwin': 68}
# Alice     68
# Bob       83
# Colin     86
# Darwin    68
# dtype: int64

# %%
s4 = pd.Series(weights, index=['Colin', 'Alice'])
s4
# Out:
# Colin    86
# Alice    68
# dtype: int64

# %%
print(s2.keys())
print(s3.keys())
s2+s3
# Out:
# Index(['Alice', 'Bob', 'Charles', 'Darwin'], dtype='object')
# Index(['Alice', 'Bob', 'Colin', 'Darwin'], dtype='object')
# Alice      136.0
# Bob        166.0
# Charles      NaN
# Colin        NaN
# Darwin     136.0
# dtype: float64

# %%
s5 = pd.Series([1000, 1000, 1000, 1000])
print(s2.values)
print(s5.values)
s2 + s5
# Out:
# [ 68  83 112  68]
# [1000 1000 1000 1000]
# Alice     NaN
# Bob       NaN
# Charles   NaN
# Darwin    NaN
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# dtype: float64

# %%
meaning = pd.Series(42, ['life', 'universe', 'everything'])
meaning
# Out:
# life          42
# universe      42
# everything    42
# dtype: int64

# %%
s6 = pd.Series([83, 68], index = ['Bob', 'Alice'], name = 'weights')
s6
# Out:
# Bob      83
# Alice    68
# Name: weights, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
temperatures = [4.4,5.1,6.1,6.2,6.1,6.1,5.7,5.2,4.7,4.1,3.9,3.5]
s7 = pd.Series(temperatures, name="Temperature")
s7.plot()
plt.show()

# %%
dates = pd.date_range('20/10/2018 17:30', periods = 12, freq = 'H')
dates
# Out:
# DatetimeIndex(['2018-10-20 17:30:00', '2018-10-20 18:30:00',
#                '2018-10-20 19:30:00', '2018-10-20 20:30:00',
#                '2018-10-20 21:30:00', '2018-10-20 22:30:00',
#                '2018-10-20 23:30:00', '2018-10-21 00:30:00',
#                '2018-10-21 01:30:00', '2018-10-21 02:30:00',
#                '2018-10-21 03:30:00', '2018-10-21 04:30:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
temp_series = pd.Series(temperatures, dates)
temp_series
# Out:
# 2018-10-20 17:30:00    4.4
# 2018-10-20 18:30:00    5.1
# 2018-10-20 19:30:00    6.1
# 2018-10-20 20:30:00    6.2
# 2018-10-20 21:30:00    6.1
# 2018-10-20 22:30:00    6.1
# 2018-10-20 23:30:00    5.7
# 2018-10-21 00:30:00    5.2
# 2018-10-21 01:30:00    4.7
# 2018-10-21 02:30:00    4.1
# 2018-10-21 03:30:00    3.9
# 2018-10-21 04:30:00    3.5
# Freq: H, dtype: float64

# %%
temp_series.plot(kind='bar')
plt.grid(True)
plt.show()

# %%
temp_series_freq_2H = temp_series.resample('2H')
temp_series_freq_2H
# Out:
# DatetimeIndexResampler [freq=<2 * Hours>, axis=0, closed=left, label=left, convention=start, base=0]

# %%
temp_series_freq_2H = temp_series_freq_2H.mean()

# %%
temp_series_freq_2H.plot(kind='bar')
plt.show()

# %%
temp_series_freq_15min = temp_series.resample('15min').mean()
temp_series_freq_15min
# Out:
# 2018-10-20 17:30:00    4.4
# 2018-10-20 17:45:00    NaN
# 2018-10-20 18:00:00    NaN
# 2018-10-20 18:15:00    NaN
# 2018-10-20 18:30:00    5.1
# 2018-10-20 18:45:00    NaN
# 2018-10-20 19:00:00    NaN
# 2018-10-20 19:15:00    NaN
# 2018-10-20 19:30:00    6.1
# 2018-10-20 19:45:00    NaN
# 2018-10-20 20:00:00    NaN
# 2018-10-20 20:15:00    NaN
# 2018-10-20 20:30:00    6.2
# 2018-10-20 20:45:00    NaN
# 2018-10-20 21:00:00    NaN
# 2018-10-20 21:15:00    NaN
# 2018-10-20 21:30:00    6.1
# 2018-10-20 21:45:00    NaN
# 2018-10-20 22:00:00    NaN
# 2018-10-20 22:15:00    NaN
# 2018-10-20 22:30:00    6.1
# 2018-10-20 22:45:00    NaN
# 2018-10-20 23:00:00    NaN
# 2018-10-20 23:15:00    NaN
# 2018-10-20 23:30:00    5.7
# 2018-10-20 23:45:00    NaN
# 2018-10-21 00:00:00    NaN
# 2018-10-21 00:15:00    NaN
# 2018-10-21 00:30:00    5.2
# 2018-10-21 00:45:00    NaN
# 2018-10-21 01:00:00    NaN
# 2018-10-21 01:15:00    NaN
# 2018-10-21 01:30:00    4.7
# 2018-10-21 01:45:00    NaN
# 2018-10-21 02:00:00    NaN
# 2018-10-21 02:15:00    NaN
# 2018-10-21 02:30:00    4.1
# 2018-10-21 02:45:00    NaN
# 2018-10-21 03:00:00    NaN
# 2018-10-21 03:15:00    NaN
# 2018-10-21 03:30:00    3.9
# 2018-10-21 03:45:00    NaN
# 2018-10-21 04:00:00    NaN
# 2018-10-21 04:15:00    NaN
# 2018-10-21 04:30:00    3.5
# Freq: 15T, dtype: float64

# %%
temp_series_freq_15min = temp_series.resample('15min').interpolate(method = 'cubic')
temp_series_freq_15min
# Out:
# 2018-10-20 17:30:00    4.400000
# 2018-10-20 17:45:00    4.452911
# 2018-10-20 18:00:00    4.605113
# 2018-10-20 18:15:00    4.829758
# 2018-10-20 18:30:00    5.100000
# 2018-10-20 18:45:00    5.388992
# 2018-10-20 19:00:00    5.669887
# 2018-10-20 19:15:00    5.915839
# 2018-10-20 19:30:00    6.100000
# 2018-10-20 19:45:00    6.203621
# 2018-10-20 20:00:00    6.240339
# 2018-10-20 20:15:00    6.231887
# 2018-10-20 20:30:00    6.200000
# 2018-10-20 20:45:00    6.163711
# 2018-10-20 21:00:00    6.131257
# 2018-10-20 21:15:00    6.108174
# 2018-10-20 21:30:00    6.100000
# 2018-10-20 21:45:00    6.108722
# 2018-10-20 22:00:00    6.122133
# 2018-10-20 22:15:00    6.124477
# 2018-10-20 22:30:00    6.100000
# 2018-10-20 22:45:00    6.037340
# 2018-10-20 23:00:00    5.942712
# 2018-10-20 23:15:00    5.826729
# 2018-10-20 23:30:00    5.700000
# 2018-10-20 23:45:00    5.571608
# 2018-10-21 00:00:00    5.444518
# 2018-10-21 00:15:00    5.320170
# 2018-10-21 00:30:00    5.200000
# 2018-10-21 00:45:00    5.084043
# 2018-10-21 01:00:00    4.966715
# 2018-10-21 01:15:00    4.841029
# 2018-10-21 01:30:00    4.700000
# 2018-10-21 01:45:00    4.540660
# 2018-10-21 02:00:00    4.376123
# 2018-10-21 02:15:00    4.223525
# 2018-10-21 02:30:00    4.100000
# 2018-10-21 02:45:00    4.017381
# 2018-10-21 03:00:00    3.966292
# 2018-10-21 03:15:00    3.932058
# 2018-10-21 03:30:00    3.900000
# 2018-10-21 03:45:00    3.855442
# 2018-10-21 04:00:00    3.783708
# 2018-10-21 04:15:00    3.670119
# 2018-10-21 04:30:00    3.500000
# Freq: 15T, dtype: float64

# %%
temp_series.plot(label="Period: 1 hour")
temp_series_freq_15min.plot(label="Period: 15 minutes")
plt.legend()
plt.show()

# %%
temp_series_ny = temp_series.tz_localize('America/New_York')
temp_series_ny
# Out:
# 2018-10-20 17:30:00-04:00    4.4
# 2018-10-20 18:30:00-04:00    5.1
# 2018-10-20 19:30:00-04:00    6.1
# 2018-10-20 20:30:00-04:00    6.2
# 2018-10-20 21:30:00-04:00    6.1
# 2018-10-20 22:30:00-04:00    6.1
# 2018-10-20 23:30:00-04:00    5.7
# 2018-10-21 00:30:00-04:00    5.2
# 2018-10-21 01:30:00-04:00    4.7
# 2018-10-21 02:30:00-04:00    4.1
# 2018-10-21 03:30:00-04:00    3.9
# 2018-10-21 04:30:00-04:00    3.5
# Freq: H, dtype: float64

# %%
temp_series_paris = temp_series_ny.tz_convert('Europe/Paris')
temp_series_paris
# Out:
# 2018-10-20 23:30:00+02:00    4.4
# 2018-10-21 00:30:00+02:00    5.1
# 2018-10-21 01:30:00+02:00    6.1
# 2018-10-21 02:30:00+02:00    6.2
# 2018-10-21 03:30:00+02:00    6.1
# 2018-10-21 04:30:00+02:00    6.1
# 2018-10-21 05:30:00+02:00    5.7
# 2018-10-21 06:30:00+02:00    5.2
# 2018-10-21 07:30:00+02:00    4.7
# 2018-10-21 08:30:00+02:00    4.1
# 2018-10-21 09:30:00+02:00    3.9
# 2018-10-21 10:30:00+02:00    3.5
# Freq: H, dtype: float64

# %%
temp_series_paris_naive = temp_series_paris.tz_localize(None)
temp_series_paris_naive
# Out:
# 2018-10-20 23:30:00    4.4
# 2018-10-21 00:30:00    5.1
# 2018-10-21 01:30:00    6.1
# 2018-10-21 02:30:00    6.2
# 2018-10-21 03:30:00    6.1
# 2018-10-21 04:30:00    6.1
# 2018-10-21 05:30:00    5.7
# 2018-10-21 06:30:00    5.2
# 2018-10-21 07:30:00    4.7
# 2018-10-21 08:30:00    4.1
# 2018-10-21 09:30:00    3.9
# 2018-10-21 10:30:00    3.5
# Freq: H, dtype: float64

# %%
try:
    temp_series_paris_naive.tz_localize("Europe/Paris")
except Exception as e:
    print(type(e))
    print(e)

# %%
temp_series_paris_naive.tz_localize("Europe/Paris", ambiguous="infer")
# Out:
# 2018-10-20 23:30:00+02:00    4.4
# 2018-10-21 00:30:00+02:00    5.1
# 2018-10-21 01:30:00+02:00    6.1
# 2018-10-21 02:30:00+02:00    6.2
# 2018-10-21 03:30:00+02:00    6.1
# 2018-10-21 04:30:00+02:00    6.1
# 2018-10-21 05:30:00+02:00    5.7
# 2018-10-21 06:30:00+02:00    5.2
# 2018-10-21 07:30:00+02:00    4.7
# 2018-10-21 08:30:00+02:00    4.1
# 2018-10-21 09:30:00+02:00    3.9
# 2018-10-21 10:30:00+02:00    3.5
# Freq: H, dtype: float64

# %%
quarters = pd.period_range('2016Q1', periods=8, freq='Q')
quarters
# Out:
# PeriodIndex(['2016Q1', '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2',
#              '2017Q3', '2017Q4'],
#             dtype='period[Q-DEC]', freq='Q-DEC')

# %%
quarters + 3
# Out:
# PeriodIndex(['2016Q4', '2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1',
#              '2018Q2', '2018Q3'],
#             dtype='period[Q-DEC]', freq='Q-DEC')

# %%
quarters.asfreq('M')
# Out:
# PeriodIndex(['2016-03', '2016-06', '2016-09', '2016-12', '2017-03', '2017-06',
#              '2017-09', '2017-12'],
#             dtype='period[M]', freq='M')

# %%
quarters.asfreq('M', how='start')
# Out:
# PeriodIndex(['2016-01', '2016-04', '2016-07', '2016-10', '2017-01', '2017-04',
#              '2017-07', '2017-10'],
#             dtype='period[M]', freq='M')

# %%
quarters.asfreq('A')
# Out:
# PeriodIndex(['2016', '2016', '2016', '2016', '2017', '2017', '2017', '2017'], dtype='period[A-DEC]', freq='A-DEC')

# %%
quarterly_revenue = pd.Series([300, 320, 290, 390, 320, 360, 310, 410], index=quarters)
quarterly_revenue
# Out:
# 2016Q1    300
# 2016Q2    320
# 2016Q3    290
# 2016Q4    390
# 2017Q1    320
# 2017Q2    360
# 2017Q3    310
# 2017Q4    410
# Freq: Q-DEC, dtype: int64

# %%
quarterly_revenue.plot(kind='line')
plt.show()

# %%
months_2019 = pd.period_range("2019", periods=12, freq="M")
one_day_after_last_days = months_2019.asfreq("D") + 1
last_bdays = one_day_after_last_days.to_timestamp() - pd.tseries.offsets.BDay()
last_bdays.to_period("H") + 9
# Out:
# PeriodIndex(['2019-01-31 09:00', '2019-02-28 09:00', '2019-03-29 09:00',
#              '2019-04-30 09:00', '2019-05-31 09:00', '2019-06-28 09:00',
#              '2019-07-31 09:00', '2019-08-30 09:00', '2019-09-30 09:00',
#              '2019-10-31 09:00', '2019-11-29 09:00', '2019-12-31 09:00'],
#             dtype='period[H]', freq='H')

# %% [markdown]
# ## Dataframe objects

# %%
people_dict = {
    'Weight': pd.Series([68, 83, 112], index=['Alice', 'Bob', 'Charles']),
    'Birthyear': pd.Series([1984, 1985, 1992], index=['Bob', 'Alice', 'Charles'], name='year'),
    'Children': pd.Series([0, 3], index=['Charles', 'Bob']),
    'Hobby': pd.Series(['Biking', 'Dancing'], index=['Alice', 'Bob']),
}
people = pd.DataFrame(people_dict)
people
# Out:
#          Weight  Birthyear  Children    Hobby
# Alice        68       1985       NaN   Biking
# Bob          83       1984       3.0  Dancing
# Charles     112       1992       0.0      NaN

# %%
people['Birthyear']
# Out:
# Alice      1985
# Bob        1984
# Charles    1992
# Name: Birthyear, dtype: int64

# %%
people[['Hobby', 'Birthyear']]
# Out:
#            Hobby  Birthyear
# Alice     Biking       1985
# Bob      Dancing       1984
# Charles      NaN       1992

# %%
d2 = pd.DataFrame(
    people_dict,
    columns = ['Birthyear', 'Weight', 'Height'],
    index = ['Bob', 'Alice', 'Eugene']
)
d2
# Out:
#         Birthyear  Weight Height
# Bob        1984.0    83.0    NaN
# Alice      1985.0    68.0    NaN
# Eugene        NaN     NaN    NaN

# %%
values = [
    [1985, np.nan, 'Biking', 68],
    [1984, 3, 'Dancing', 83],
    [1992, 0, np.nan, 112]
]
d3 = pd.DataFrame(
    values,
    columns = ['Birthyear', 'Childred', 'Hobby', 'Weight'],
    index = ['Alice', 'Bob', 'Charles']
)
d3
# Out:
#          Birthyear  Childred    Hobby  Weight
# Alice         1985       NaN   Biking      68
# Bob           1984       3.0  Dancing      83
# Charles       1992       0.0      NaN     112

# %%
masked_array = np.ma.asarray(values, dtype=np.object)
masked_array[(0,2), (1,2)] = np.ma.masked
d3 = pd.DataFrame(
        masked_array,
        columns=["birthyear", "children", "hobby", "weight"],
        index=["alice", "bob", "charles"]
     )
d3
# Out:
#         birthyear children    hobby weight
# alice        1985      NaN   Biking     68
# bob          1984        3  Dancing     83
# charles      1992        0      NaN    112

# %%
people = pd.DataFrame({
    "birthyear": {"alice":1985, "bob": 1984, "charles": 1992},
    "hobby": {"alice":"Biking", "bob": "Dancing"},
    "weight": {"alice":68, "bob": 83, "charles": 112},
    "children": {"bob": 3, "charles": 0}
})
people
# Out:
#          birthyear    hobby  weight  children
# alice         1985   Biking      68       NaN
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
d5 = pd.DataFrame(
    {
        ('Public', 'Birthyear'):
            {('Paris', 'Alice'): 1985, ('Paris', 'Bob'): 1984, ('London', 'Charles'): 1992},
        ('Public', 'Hobby'):
            {('Paris', 'Alice'): 'Biking', ('Paris', 'Bob'): 'Dancing'},
        ('Private', 'Weight'):
            {('Paris', 'Alice'): 68, ('Paris', 'Bob'): 83, ('London', 'Charles'): 112},
        ('Private', 'Children'):
            {('Paris', 'Alice'): np.nan, ('Paris', 'Bob'): 3, ('London', 'Charles'): 0}
    }
)
d5
# Out:
#                   Public          Private
#                Birthyear    Hobby  Weight Children
# London Charles      1992      NaN     112      0.0
# Paris  Alice        1985   Biking      68      NaN
#        Bob          1984  Dancing      83      3.0

# %%
d5['Public']
# Out:
#                 Birthyear    Hobby
# London Charles       1992      NaN
# Paris  Alice         1985   Biking
#        Bob           1984  Dancing

# %%
d5['Public', 'Hobby']
# Out:
# London  Charles        NaN
# Paris   Alice       Biking
#         Bob        Dancing
# Name: (Public, Hobby), dtype: object

# %%
d5.columns = d5.columns.droplevel(level=0)
d5
# Out:
#                 Birthyear    Hobby  Weight  Children
# London Charles       1992      NaN     112       0.0
# Paris  Alice         1985   Biking      68       NaN
#        Bob           1984  Dancing      83       3.0

# %%
d6 = d5.T
d6
# Out:
#            London   Paris
#           Charles   Alice      Bob
# Birthyear    1992    1985     1984
# Hobby         NaN  Biking  Dancing
# Weight        112      68       83
# Children        0     NaN        3

# %%
d7 = d6.stack()
d7
# Out:
#                   London    Paris
# Birthyear Alice      NaN     1985
#           Bob        NaN     1984
#           Charles   1992      NaN
# Hobby     Alice      NaN   Biking
#           Bob        NaN  Dancing
# Weight    Alice      NaN       68
#           Bob        NaN       83
#           Charles    112      NaN
# Children  Bob        NaN        3
#           Charles      0      NaN

# %%
d8 = d7.unstack()
d8
# Out:
#           London                Paris
#            Alice  Bob Charles   Alice      Bob Charles
# Birthyear    NaN  NaN    1992    1985     1984     NaN
# Hobby        NaN  NaN     NaN  Biking  Dancing     NaN
# Weight       NaN  NaN     112      68       83     NaN
# Children     NaN  NaN       0     NaN        3     NaN

# %%
d9 = d8.unstack()
d9
# Out:
# London  Alice    Birthyear        NaN
#                  Hobby            NaN
#                  Weight           NaN
#                  Children         NaN
#         Bob      Birthyear        NaN
#                  Hobby            NaN
#                  Weight           NaN
#                  Children         NaN
#         Charles  Birthyear       1992
#                  Hobby            NaN
#                  Weight           112
#                  Children           0
# Paris   Alice    Birthyear       1985
#                  Hobby         Biking
#                  Weight            68
#                  Children         NaN
#         Bob      Birthyear       1984
#                  Hobby        Dancing
#                  Weight            83
#                  Children           3
#         Charles  Birthyear        NaN
#                  Hobby            NaN
#                  Weight           NaN
#                  Children         NaN
# dtype: object

# %%
d10 = d9.unstack(level=(0,1))
d10
# Out:
#           London                Paris
#            Alice  Bob Charles   Alice      Bob Charles
# Birthyear    NaN  NaN    1992    1985     1984     NaN
# Hobby        NaN  NaN     NaN  Biking  Dancing     NaN
# Weight       NaN  NaN     112      68       83     NaN
# Children     NaN  NaN       0     NaN        3     NaN

# %%
people
# Out:
#          birthyear    hobby  weight  children
# alice         1985   Biking      68       NaN
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
people.loc['charles']
# Out:
# birthyear    1992
# hobby         NaN
# weight        112
# children        0
# Name: charles, dtype: object

# %%
people.iloc[1]
# Out:
# birthyear       1984
# hobby        Dancing
# weight            83
# children           3
# Name: bob, dtype: object

# %%
people[people['birthyear'] < 1990]
# Out:
#        birthyear    hobby  weight  children
# alice       1985   Biking      68       NaN
# bob         1984  Dancing      83       3.0

# %%
people['birthyear'] < 1990
# Out:
# alice       True
# bob         True
# charles    False
# Name: birthyear, dtype: bool

# %%
people['Age'] = 2018 - people['birthyear']
people['Over 30'] = people['Age'] > 30
birthyears = people.pop('birthyear')
del people['children']
people
# Out:
#            hobby  weight  Age  Over 30
# alice     Biking      68   33     True
# bob      Dancing      83   34     True
# charles      NaN     112   26    False

# %%
people["pets"] = pd.Series({"bob": 0, "charles": 5, "eugene":1})  # alice is missing, eugene is ignored
people
# Out:
#            hobby  weight  Age  Over 30  pets
# alice     Biking      68   33     True   NaN
# bob      Dancing      83   34     True   0.0
# charles      NaN     112   26    False   5.0

# %%
del people['height']
people.insert(1, "height", [172, 181, 185])
people
# Out:
#            hobby  height  weight  Age  Over 30  pets
# alice     Biking     172      68   33     True   NaN
# bob      Dancing     181      83   34     True   0.0
# charles      NaN     185     112   26    False   5.0

# %%
people.assign(
    body_mass_index = people["weight"] / (people["height"] / 100) ** 2,
    has_pets = people["pets"] > 0
)
# Out:
#            hobby  height  weight  Age  Over 30  pets  body_mass_index  \
# alice     Biking     172      68   33     True   NaN        22.985398
# bob      Dancing     181      83   34     True   0.0        25.335002
# charles      NaN     185     112   26    False   5.0        32.724617
#
#          has_pets
# alice       False
# bob         False
# charles      True

# %%
d6 = people.assign(body_mass_index = people["weight"] / (people["height"] / 100) ** 2)
d6.assign(overweight = d6["body_mass_index"] > 25)
# Out:
#            hobby  height  weight  Age  Over 30  pets  body_mass_index  \
# alice     Biking     172      68   33     True   NaN        22.985398
# bob      Dancing     181      83   34     True   0.0        25.335002
# charles      NaN     185     112   26    False   5.0        32.724617
#
#          overweight
# alice         False
# bob            True
# charles        True

# %%
(people
     .assign(body_mass_index = lambda df: df["weight"] / (df["height"] / 100) ** 2)
     .assign(overweight = lambda df: df["body_mass_index"] > 25)
)
# Out:
#            hobby  height  weight  Age  Over 30  pets  body_mass_index  \
# alice     Biking     172      68   33     True   NaN        22.985398
# bob      Dancing     181      83   34     True   0.0        25.335002
# charles      NaN     185     112   26    False   5.0        32.724617
#
#          overweight
# alice         False
# bob            True
# charles        True

# %%
much_data = np.fromfunction(lambda x,y: (x+y*y)%17*11, (10000, 26))
large_df = pd.DataFrame(much_data, columns = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'))
large_df[large_df % 16 == 0] = np.nan
large_df.insert(3, 'SomeText', 'Blehblehbleh')
large_df
# Out:
#           A      B      C      SomeText      D      E      F      G      H  \
# 0       NaN   11.0   44.0  Blehblehbleh   99.0    NaN   88.0   22.0  165.0
# 1      11.0   22.0   55.0  Blehblehbleh  110.0    NaN   99.0   33.0    NaN
# 2      22.0   33.0   66.0  Blehblehbleh  121.0   11.0  110.0   44.0    NaN
# 3      33.0   44.0   77.0  Blehblehbleh  132.0   22.0  121.0   55.0   11.0
# 4      44.0   55.0   88.0  Blehblehbleh  143.0   33.0  132.0   66.0   22.0
# 5      55.0   66.0   99.0  Blehblehbleh  154.0   44.0  143.0   77.0   33.0
# 6      66.0   77.0  110.0  Blehblehbleh  165.0   55.0  154.0   88.0   44.0
# 7      77.0   88.0  121.0  Blehblehbleh    NaN   66.0  165.0   99.0   55.0
# 8      88.0   99.0  132.0  Blehblehbleh    NaN   77.0    NaN  110.0   66.0
# 9      99.0  110.0  143.0  Blehblehbleh   11.0   88.0    NaN  121.0   77.0
# 10    110.0  121.0  154.0  Blehblehbleh   22.0   99.0   11.0  132.0   88.0
# 11    121.0  132.0  165.0  Blehblehbleh   33.0  110.0   22.0  143.0   99.0
# 12    132.0  143.0    NaN  Blehblehbleh   44.0  121.0   33.0  154.0  110.0
# 13    143.0  154.0    NaN  Blehblehbleh   55.0  132.0   44.0  165.0  121.0
# 14    154.0  165.0   11.0  Blehblehbleh   66.0  143.0   55.0    NaN  132.0
# 15    165.0    NaN   22.0  Blehblehbleh   77.0  154.0   66.0    NaN  143.0
# 16      NaN    NaN   33.0  Blehblehbleh   88.0  165.0   77.0   11.0  154.0
# 17      NaN   11.0   44.0  Blehblehbleh   99.0    NaN   88.0   22.0  165.0
# 18     11.0   22.0   55.0  Blehblehbleh  110.0    NaN   99.0   33.0    NaN
# 19     22.0   33.0   66.0  Blehblehbleh  121.0   11.0  110.0   44.0    NaN
# 20     33.0   44.0   77.0  Blehblehbleh  132.0   22.0  121.0   55.0   11.0
# 21     44.0   55.0   88.0  Blehblehbleh  143.0   33.0  132.0   66.0   22.0
# 22     55.0   66.0   99.0  Blehblehbleh  154.0   44.0  143.0   77.0   33.0
# 23     66.0   77.0  110.0  Blehblehbleh  165.0   55.0  154.0   88.0   44.0
# 24     77.0   88.0  121.0  Blehblehbleh    NaN   66.0  165.0   99.0   55.0
# 25     88.0   99.0  132.0  Blehblehbleh    NaN   77.0    NaN  110.0   66.0
# 26     99.0  110.0  143.0  Blehblehbleh   11.0   88.0    NaN  121.0   77.0
# 27    110.0  121.0  154.0  Blehblehbleh   22.0   99.0   11.0  132.0   88.0
# 28    121.0  132.0  165.0  Blehblehbleh   33.0  110.0   22.0  143.0   99.0
# 29    132.0  143.0    NaN  Blehblehbleh   44.0  121.0   33.0  154.0  110.0
# ...     ...    ...    ...           ...    ...    ...    ...    ...    ...
# 9970   88.0   99.0  132.0  Blehblehbleh    NaN   77.0    NaN  110.0   66.0
# 9971   99.0  110.0  143.0  Blehblehbleh   11.0   88.0    NaN  121.0   77.0
# 9972  110.0  121.0  154.0  Blehblehbleh   22.0   99.0   11.0  132.0   88.0
# 9973  121.0  132.0  165.0  Blehblehbleh   33.0  110.0   22.0  143.0   99.0
# 9974  132.0  143.0    NaN  Blehblehbleh   44.0  121.0   33.0  154.0  110.0
# 9975  143.0  154.0    NaN  Blehblehbleh   55.0  132.0   44.0  165.0  121.0
# 9976  154.0  165.0   11.0  Blehblehbleh   66.0  143.0   55.0    NaN  132.0
# 9977  165.0    NaN   22.0  Blehblehbleh   77.0  154.0   66.0    NaN  143.0
# 9978    NaN    NaN   33.0  Blehblehbleh   88.0  165.0   77.0   11.0  154.0
# 9979    NaN   11.0   44.0  Blehblehbleh   99.0    NaN   88.0   22.0  165.0
# 9980   11.0   22.0   55.0  Blehblehbleh  110.0    NaN   99.0   33.0    NaN
# 9981   22.0   33.0   66.0  Blehblehbleh  121.0   11.0  110.0   44.0    NaN
# 9982   33.0   44.0   77.0  Blehblehbleh  132.0   22.0  121.0   55.0   11.0
# 9983   44.0   55.0   88.0  Blehblehbleh  143.0   33.0  132.0   66.0   22.0
# 9984   55.0   66.0   99.0  Blehblehbleh  154.0   44.0  143.0   77.0   33.0
# 9985   66.0   77.0  110.0  Blehblehbleh  165.0   55.0  154.0   88.0   44.0
# 9986   77.0   88.0  121.0  Blehblehbleh    NaN   66.0  165.0   99.0   55.0
# 9987   88.0   99.0  132.0  Blehblehbleh    NaN   77.0    NaN  110.0   66.0
# 9988   99.0  110.0  143.0  Blehblehbleh   11.0   88.0    NaN  121.0   77.0
# 9989  110.0  121.0  154.0  Blehblehbleh   22.0   99.0   11.0  132.0   88.0
# 9990  121.0  132.0  165.0  Blehblehbleh   33.0  110.0   22.0  143.0   99.0
# 9991  132.0  143.0    NaN  Blehblehbleh   44.0  121.0   33.0  154.0  110.0
# 9992  143.0  154.0    NaN  Blehblehbleh   55.0  132.0   44.0  165.0  121.0
# 9993  154.0  165.0   11.0  Blehblehbleh   66.0  143.0   55.0    NaN  132.0
# 9994  165.0    NaN   22.0  Blehblehbleh   77.0  154.0   66.0    NaN  143.0
# 9995    NaN    NaN   33.0  Blehblehbleh   88.0  165.0   77.0   11.0  154.0
# 9996    NaN   11.0   44.0  Blehblehbleh   99.0    NaN   88.0   22.0  165.0
# 9997   11.0   22.0   55.0  Blehblehbleh  110.0    NaN   99.0   33.0    NaN
# 9998   22.0   33.0   66.0  Blehblehbleh  121.0   11.0  110.0   44.0    NaN
# 9999   33.0   44.0   77.0  Blehblehbleh  132.0   22.0  121.0   55.0   11.0
#
#           I  ...        Q      R      S      T      U      V      W      X  \
# 0     143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 1     154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 2     165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 3       NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 4       NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 5      11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 6      22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 7      33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 8      44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9      55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 10     66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 11     77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 12     88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 13     99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 14    110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 15    121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 16    132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 17    143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 18    154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 19    165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 20      NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 21      NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 22     11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 23     22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 24     33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 25     44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 26     55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 27     66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 28     77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 29     88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# ...     ...  ...      ...    ...    ...    ...    ...    ...    ...    ...
# 9970   44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9971   55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 9972   66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 9973   77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 9974   88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 9975   99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 9976  110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 9977  121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 9978  132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 9979  143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 9980  154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 9981  165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 9982    NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
# 9983    NaN  ...     55.0   44.0   55.0   88.0  143.0   33.0  132.0   66.0
# 9984   11.0  ...     66.0   55.0   66.0   99.0  154.0   44.0  143.0   77.0
# 9985   22.0  ...     77.0   66.0   77.0  110.0  165.0   55.0  154.0   88.0
# 9986   33.0  ...     88.0   77.0   88.0  121.0    NaN   66.0  165.0   99.0
# 9987   44.0  ...     99.0   88.0   99.0  132.0    NaN   77.0    NaN  110.0
# 9988   55.0  ...    110.0   99.0  110.0  143.0   11.0   88.0    NaN  121.0
# 9989   66.0  ...    121.0  110.0  121.0  154.0   22.0   99.0   11.0  132.0
# 9990   77.0  ...    132.0  121.0  132.0  165.0   33.0  110.0   22.0  143.0
# 9991   88.0  ...    143.0  132.0  143.0    NaN   44.0  121.0   33.0  154.0
# 9992   99.0  ...    154.0  143.0  154.0    NaN   55.0  132.0   44.0  165.0
# 9993  110.0  ...    165.0  154.0  165.0   11.0   66.0  143.0   55.0    NaN
# 9994  121.0  ...      NaN  165.0    NaN   22.0   77.0  154.0   66.0    NaN
# 9995  132.0  ...      NaN    NaN    NaN   33.0   88.0  165.0   77.0   11.0
# 9996  143.0  ...     11.0    NaN   11.0   44.0   99.0    NaN   88.0   22.0
# 9997  154.0  ...     22.0   11.0   22.0   55.0  110.0    NaN   99.0   33.0
# 9998  165.0  ...     33.0   22.0   33.0   66.0  121.0   11.0  110.0   44.0
# 9999    NaN  ...     44.0   33.0   44.0   77.0  132.0   22.0  121.0   55.0
#
#           Y      Z
# 0     165.0  143.0
# 1       NaN  154.0
# 2       NaN  165.0
# 3      11.0    NaN
# 4      22.0    NaN
# 5      33.0   11.0
# 6      44.0   22.0
# 7      55.0   33.0
# 8      66.0   44.0
# 9      77.0   55.0
# 10     88.0   66.0
# 11     99.0   77.0
# 12    110.0   88.0
# 13    121.0   99.0
# 14    132.0  110.0
# 15    143.0  121.0
# 16    154.0  132.0
# 17    165.0  143.0
# 18      NaN  154.0
# 19      NaN  165.0
# 20     11.0    NaN
# 21     22.0    NaN
# 22     33.0   11.0
# 23     44.0   22.0
# 24     55.0   33.0
# 25     66.0   44.0
# 26     77.0   55.0
# 27     88.0   66.0
# 28     99.0   77.0
# 29    110.0   88.0
# ...     ...    ...
# 9970   66.0   44.0
# 9971   77.0   55.0
# 9972   88.0   66.0
# 9973   99.0   77.0
# 9974  110.0   88.0
# 9975  121.0   99.0
# 9976  132.0  110.0
# 9977  143.0  121.0
# 9978  154.0  132.0
# 9979  165.0  143.0
# 9980    NaN  154.0
# 9981    NaN  165.0
# 9982   11.0    NaN
# 9983   22.0    NaN
# 9984   33.0   11.0
# 9985   44.0   22.0
# 9986   55.0   33.0
# 9987   66.0   44.0
# 9988   77.0   55.0
# 9989   88.0   66.0
# 9990   99.0   77.0
# 9991  110.0   88.0
# 9992  121.0   99.0
# 9993  132.0  110.0
# 9994  143.0  121.0
# 9995  154.0  132.0
# 9996  165.0  143.0
# 9997    NaN  154.0
# 9998    NaN  165.0
# 9999   11.0    NaN
#
# [10000 rows x 27 columns]

# %%
large_df.head()
# Out:
#       A     B     C      SomeText      D     E      F     G      H      I  \
# 0   NaN  11.0  44.0  Blehblehbleh   99.0   NaN   88.0  22.0  165.0  143.0
# 1  11.0  22.0  55.0  Blehblehbleh  110.0   NaN   99.0  33.0    NaN  154.0
# 2  22.0  33.0  66.0  Blehblehbleh  121.0  11.0  110.0  44.0    NaN  165.0
# 3  33.0  44.0  77.0  Blehblehbleh  132.0  22.0  121.0  55.0   11.0    NaN
# 4  44.0  55.0  88.0  Blehblehbleh  143.0  33.0  132.0  66.0   22.0    NaN
#
#    ...       Q     R     S     T      U     V      W     X      Y      Z
# 0  ...    11.0   NaN  11.0  44.0   99.0   NaN   88.0  22.0  165.0  143.0
# 1  ...    22.0  11.0  22.0  55.0  110.0   NaN   99.0  33.0    NaN  154.0
# 2  ...    33.0  22.0  33.0  66.0  121.0  11.0  110.0  44.0    NaN  165.0
# 3  ...    44.0  33.0  44.0  77.0  132.0  22.0  121.0  55.0   11.0    NaN
# 4  ...    55.0  44.0  55.0  88.0  143.0  33.0  132.0  66.0   22.0    NaN
#
# [5 rows x 27 columns]

# %%
large_df.tail()
# Out:
#          A     B     C      SomeText      D      E      F     G      H      I  \
# 9995   NaN   NaN  33.0  Blehblehbleh   88.0  165.0   77.0  11.0  154.0  132.0
# 9996   NaN  11.0  44.0  Blehblehbleh   99.0    NaN   88.0  22.0  165.0  143.0
# 9997  11.0  22.0  55.0  Blehblehbleh  110.0    NaN   99.0  33.0    NaN  154.0
# 9998  22.0  33.0  66.0  Blehblehbleh  121.0   11.0  110.0  44.0    NaN  165.0
# 9999  33.0  44.0  77.0  Blehblehbleh  132.0   22.0  121.0  55.0   11.0    NaN
#
#       ...       Q     R     S     T      U      V      W     X      Y      Z
# 9995  ...     NaN   NaN   NaN  33.0   88.0  165.0   77.0  11.0  154.0  132.0
# 9996  ...    11.0   NaN  11.0  44.0   99.0    NaN   88.0  22.0  165.0  143.0
# 9997  ...    22.0  11.0  22.0  55.0  110.0    NaN   99.0  33.0    NaN  154.0
# 9998  ...    33.0  22.0  33.0  66.0  121.0   11.0  110.0  44.0    NaN  165.0
# 9999  ...    44.0  33.0  44.0  77.0  132.0   22.0  121.0  55.0   11.0    NaN
#
# [5 rows x 27 columns]

# %%
large_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 27 columns):
# A           8823 non-null float64
# B           8824 non-null float64
# C           8824 non-null float64
# SomeText    10000 non-null object
# D           8824 non-null float64
# E           8822 non-null float64
# F           8824 non-null float64
# G           8824 non-null float64
# H           8822 non-null float64
# I           8823 non-null float64
# J           8823 non-null float64
# K           8822 non-null float64
# L           8824 non-null float64
# M           8824 non-null float64
# N           8822 non-null float64
# O           8824 non-null float64
# P           8824 non-null float64
# Q           8824 non-null float64
# R           8823 non-null float64
# S           8824 non-null float64
# T           8824 non-null float64
# U           8824 non-null float64
# V           8822 non-null float64
# W           8824 non-null float64
# X           8824 non-null float64
# Y           8822 non-null float64
# Z           8823 non-null float64
# dtypes: float64(26), object(1)
# memory usage: 2.1+ MB

# %%
large_df.describe()
# Out:
#                  A            B            C            D            E  \
# count  8823.000000  8824.000000  8824.000000  8824.000000  8822.000000
# mean     87.977559    87.972575    87.987534    88.012466    87.983791
# std      47.535911    47.535523    47.521679    47.521679    47.535001
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#                  F            G            H            I            J  \
# count  8824.000000  8824.000000  8822.000000  8823.000000  8823.000000
# mean     88.007480    87.977561    88.000000    88.022441    88.022441
# std      47.519371    47.529755    47.536879    47.535911    47.535911
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#           ...                 Q            R            S            T  \
# count     ...       8824.000000  8823.000000  8824.000000  8824.000000
# mean      ...         87.972575    87.977559    87.972575    87.987534
# std       ...         47.535523    47.535911    47.535523    47.521679
# min       ...         11.000000    11.000000    11.000000    11.000000
# 25%       ...         44.000000    44.000000    44.000000    44.000000
# 50%       ...         88.000000    88.000000    88.000000    88.000000
# 75%       ...        132.000000   132.000000   132.000000   132.000000
# max       ...        165.000000   165.000000   165.000000   165.000000
#
#                  U            V            W            X            Y  \
# count  8824.000000  8822.000000  8824.000000  8824.000000  8822.000000
# mean     88.012466    87.983791    88.007480    87.977561    88.000000
# std      47.521679    47.535001    47.519371    47.529755    47.536879
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#                  Z
# count  8823.000000
# mean     88.022441
# std      47.535911
# min      11.000000
# 25%      44.000000
# 50%      88.000000
# 75%     132.000000
# max     165.000000
#
# [8 rows x 26 columns]

# %%
my_df = pd.DataFrame(
    [["Biking", 68.5, 1985, np.nan], ["Dancing", 83.1, 1984, 3]], 
    columns=["hobby","weight","birthyear","children"],
    index=["alice", "bob"]
)
my_df
# Out:
#          hobby  weight  birthyear  children
# alice   Biking    68.5       1985       NaN
# bob    Dancing    83.1       1984       3.0

# %%
my_df.to_csv("my_df.csv")
my_df.to_html("my_df.html")
my_df.to_json("my_df.json")

# %%
for filename in ("my_df.csv", "my_df.html", "my_df.json"):
    print("#", filename)
    with open(filename, "rt") as f:
        print(f.read())
        print()
# Out:
# # my_df.csv
# ,hobby,weight,birthyear,children
# alice,Biking,68.5,1985,
# bob,Dancing,83.1,1984,3.0
#
#
# # my_df.html
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>hobby</th>
#       <th>weight</th>
#       <th>birthyear</th>
#       <th>children</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>alice</th>
#       <td>Biking</td>
#       <td>68.5</td>
#       <td>1985</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>bob</th>
#       <td>Dancing</td>
#       <td>83.1</td>
#       <td>1984</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
#
# # my_df.json
# {"hobby":{"alice":"Biking","bob":"Dancing"},"weight":{"alice":68.5,"bob":83.1},"birthyear":{"alice":1985,"bob":1984},"children":{"alice":null,"bob":3.0}}

# %%
my_df_loaded = pd.read_csv("my_df.csv", index_col=0)
my_df_loaded
# Out:
#          hobby  weight  birthyear  children
# alice   Biking    68.5       1985       NaN
# bob    Dancing    83.1       1984       3.0

# %%
us_cities = None
try:
    csv_url = "http://simplemaps.com/files/cities.csv"
    us_cities = pd.read_csv(csv_url, index_col=0)
    us_cities = us_cities.head()
except IOError as e:
    print(e)
us_cities
# Out:
# HTTP Error 403: Forbidden

# %%
city_loc = pd.DataFrame(
    [
        ["CA", "San Francisco", 37.781334, -122.416728],
        ["NY", "New York", 40.705649, -74.008344],
        ["FL", "Miami", 25.791100, -80.320733],
        ["OH", "Cleveland", 41.473508, -81.739791],
        ["UT", "Salt Lake City", 40.755851, -111.896657]
    ], columns=["state", "city", "lat", "lng"])
city_loc
# Out:
#   state            city        lat         lng
# 0    CA   San Francisco  37.781334 -122.416728
# 1    NY        New York  40.705649  -74.008344
# 2    FL           Miami  25.791100  -80.320733
# 3    OH       Cleveland  41.473508  -81.739791
# 4    UT  Salt Lake City  40.755851 -111.896657

# %%
city_pop = pd.DataFrame(
    [
        [808976, "San Francisco", "California"],
        [8363710, "New York", "New-York"],
        [413201, "Miami", "Florida"],
        [2242193, "Houston", "Texas"]
    ], index=[3,4,5,6], columns=["population", "city", "state"])
city_pop
# Out:
#    population           city       state
# 3      808976  San Francisco  California
# 4     8363710       New York    New-York
# 5      413201          Miami     Florida
# 6     2242193        Houston       Texas

# %%
pd.merge(left=city_loc, right=city_pop, on="city")
# Out:
#   state_x           city        lat         lng  population     state_y
# 0      CA  San Francisco  37.781334 -122.416728      808976  California
# 1      NY       New York  40.705649  -74.008344     8363710    New-York
# 2      FL          Miami  25.791100  -80.320733      413201     Florida

# %%
all_cities = pd.merge(left=city_loc, right=city_pop, on="city", how="outer")
all_cities
# Out:
#   state_x            city        lat         lng  population     state_y
# 0      CA   San Francisco  37.781334 -122.416728    808976.0  California
# 1      NY        New York  40.705649  -74.008344   8363710.0    New-York
# 2      FL           Miami  25.791100  -80.320733    413201.0     Florida
# 3      OH       Cleveland  41.473508  -81.739791         NaN         NaN
# 4      UT  Salt Lake City  40.755851 -111.896657         NaN         NaN
# 5     NaN         Houston        NaN         NaN   2242193.0       Texas

# %%
pd.merge(left=city_loc, right=city_pop, on="city", how="right")
# Out:
#   state_x           city        lat         lng  population     state_y
# 0      CA  San Francisco  37.781334 -122.416728      808976  California
# 1      NY       New York  40.705649  -74.008344     8363710    New-York
# 2      FL          Miami  25.791100  -80.320733      413201     Florida
# 3     NaN        Houston        NaN         NaN     2242193       Texas

# %%
pd.merge(left=city_loc, right=city_pop, on="city", how="left")
# Out:
#   state_x            city        lat         lng  population     state_y
# 0      CA   San Francisco  37.781334 -122.416728    808976.0  California
# 1      NY        New York  40.705649  -74.008344   8363710.0    New-York
# 2      FL           Miami  25.791100  -80.320733    413201.0     Florida
# 3      OH       Cleveland  41.473508  -81.739791         NaN         NaN
# 4      UT  Salt Lake City  40.755851 -111.896657         NaN         NaN

# %%
city_pop2 = city_pop.copy()
city_pop2.columns = ["population", "name", "state"]
pd.merge(left=city_loc, right=city_pop2, left_on="city", right_on="name")
# Out:
#   state_x           city        lat         lng  population           name  \
# 0      CA  San Francisco  37.781334 -122.416728      808976  San Francisco
# 1      NY       New York  40.705649  -74.008344     8363710       New York
# 2      FL          Miami  25.791100  -80.320733      413201          Miami
#
#       state_y
# 0  California
# 1    New-York
# 2     Florida

# %%
result_concat = pd.concat([city_loc, city_pop])
result_concat
# Out:
# C:\ProgramData\Anaconda3_5\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#              city        lat         lng  population       state
# 0   San Francisco  37.781334 -122.416728         NaN          CA
# 1        New York  40.705649  -74.008344         NaN          NY
# 2           Miami  25.791100  -80.320733         NaN          FL
# 3       Cleveland  41.473508  -81.739791         NaN          OH
# 4  Salt Lake City  40.755851 -111.896657         NaN          UT
# 3   San Francisco        NaN         NaN    808976.0  California
# 4        New York        NaN         NaN   8363710.0    New-York
# 5           Miami        NaN         NaN    413201.0     Florida
# 6         Houston        NaN         NaN   2242193.0       Texas
